# %%
# Standard library imports
import os
import re

# Third-party library imports
import geocoder
import requests
import pandas as pd
from bs4 import BeautifulSoup
from dotenv import load_dotenv

# Local imports
from customScripts import state_mapping, all_states

# Load environment variables from .env file
load_dotenv()

# Access the Bing Maps API key from the environment variable
bing_api_key = os.getenv('BING_MAPS_API_KEY')

# %% [markdown]
# # Golf Digest

# %%
golf_digest_public_url = "https://www.golfdigest.com/story/americas-100-greatest-public-golf-courses-ranking"
response = requests.get(golf_digest_public_url)
html_content = response.text
soup = BeautifulSoup(html_content, "html.parser")

all_data = soup.find_all(class_ = "o-InfoBox")

all_courses = [x.find_all(class_ = "o-InfoBox__a-Title")[0].get_text(strip=True) for x in all_data]

course_locations = [x.find_all(class_ = "o-InfoBox__a-Subtitle")[0].get_text(strip=True) for x in all_data]

panelist_ratings = []
for course in all_data:
    try:
        panelist_ratings.append(2 * float(course.find_all(class_ = "o-InfoBox__a-Rating")[0].find('div', class_= 'o-Rating')['data-score']))
    except IndexError:
        panelist_ratings.append("-")

# %%
golf_digest_public = pd.DataFrame(columns=["CourseName","Played", "Date", "Notes", "CurrentRanking", "PastRanking","PanelistRating", "City", "State", "Country", "Architect", "Latitude", "Longitude"])

for course, course_location, panelist_rating in zip(all_courses, course_locations, panelist_ratings):
    current_ranking = course.split(".")[0]
    last_ranking = course.split(".")[1].split(")")[0].split("(")[1]
    course_name = course.split(") ")[-1]

    city = course_location.split(", ")[0]
    state = course_location.split(", ")[-1]

    location = geocoder.bing(f"{course_name} {city}, {state}", key=bing_api_key).json    
    latitude = location['lat']
    longtitude = location['lng']
    country = location['country']

    golf_digest_public.loc[len(golf_digest_public)] = [course_name, "", "", "", current_ranking, last_ranking, panelist_rating, city, state, country, "-", latitude, longtitude]

# %%
state = "Illinois"
url = f"https://www.golfdigest.com/places-to-play/collections/{state}-best-golf-courses-rankings"
response = requests.get(url)
html_content = response.text
soup = BeautifulSoup(html_content, "html.parser")

all_data = soup.find_all(class_ = "o-InfoBox")
all_data
# Out:
# []

# %%
states_data =  {}

for state in all_states:
    states_data[state] = pd.DataFrame(columns=["CourseName","Played", "Date", "Notes", "CurrentRanking", "PastRanking", "PanelistRating", "City", "State", "Country", "Architect", "Latitude", "Longitude"])

for state, df in states_data.items():
    print()

    url = f"https://www.golfdigest.com/places-to-play/collections/{state.lower()}-best-golf-courses-rankings"
    response = requests.get(url)
    html_content = response.text
    soup = BeautifulSoup(html_content, "html.parser")

    all_data = soup.find_all(class_ = "o-InfoBox")

    all_courses = [x.find_all(class_ = "o-InfoBox__a-Title")[0].get_text(strip=True) for x in all_data]

    course_locations = [x.find_all(class_ = "o-InfoBox__a-Subtitle")[0].get_text(strip=True) for x in all_data]

    panelist_ratings = []
    for course in all_data:
        try:
            panelist_ratings.append(2 * float(course.find_all(class_ = "o-InfoBox__a-Rating")[0].find('div', class_= 'o-Rating')['data-score']))
        except IndexError:
            panelist_ratings.append("-")

    for course, course_location, panelist_rating in zip(all_courses, course_locations, panelist_ratings):

        try:
            current_ranking = re.search(r'(\d+)\s*\((NR|NEW|\d+)\)', course).group(1)
            last_ranking = re.search(r'\((NR|NEW|\d+)\)', course).group(1)
            course_name = re.search(r'\)\s*(\w.*)', course).group(1)

            city = course_location.split(", ")[0]
            state_acryn = course_location.split(", ")[-1]

        except Exception as e:
            print(f"Issue finding ranking data for {course} in {state}.\n{e}\n")

        try:
            location = geocoder.bing(f"{course_name} {city}, {state_acryn}", key=bing_api_key).json    
            latitude = location['lat']
            longtitude = location['lng']
            country = location['country']
        except TypeError:
            print(f"Issue finding location data for {course} in {state}.")
            latitude, longtitude, country = "Err.", "Err.", "United States"
        df.loc[len(df)] = [course_name, "", "", "", current_ranking, last_ranking, panelist_rating, city, state_acryn, country, "-", latitude, longtitude]

    #states_data.append((state, state_data))
# Out:
# Issue finding ranking data for 1. (1) Moose Run Golf Course: Creek in Alaska.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 2. (NR) Anchorage Golf Course in Alaska.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 3. (NR) Settlers Bay Golf Course in Alaska.
# 'NoneType' object has no attribute 'group'
#
#
# Issue finding ranking data for 1. (1) Shoal Creek in Alabama.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 2. (2) The Country Club of Birmingham: West in Alabama.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 3. (3) The Ledges in Alabama.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 4. (4) Turtle Point Yacht & Country Club in Alabama.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 5. (6) Old Overton Club in Alabama.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 6. (5) Robert Trent Jones Golf Trail At Capitol Hill: The Judge in Alabama.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 7. (7) Vestavia Country Club: Championship in Alabama.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 8. (NR) Robert Trent Jones Golf Trail At Grand National: The Lakes in Alabama.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 9. (NR) Greystone Golf & Country Club: Legacy Course in Alabama.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 10. (NR) Greystone Golf & Country Club: Founders Course in Alabama.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 11. (NR) Robert Trent Jones Golf Trail at Ross Bridge in Alabama.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 12. (8) Robert Trent Jones Golf Trail At Grand National: The Links in Alabama.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 13. (10) FarmLinks Golf Club in Alabama.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 14. (9) Kiva Dunes Golf Course in Alabama.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 15. (NR) Willow Point Golf & Country Club in Alabama.
# 'NoneType' object has no attribute 'group'
#
#
# Issue finding ranking data for 1. (1) The Alotian Club in Arkansas.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 2. (2) Blessings Golf Club in Arkansas.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 3. (4) The Country Club of Little Rock in Arkansas.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 4. (5) Texarkana Country Club in Arkansas.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 5. (3) Diamante Country Club in Arkansas.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 6. (NR) Pleasant Valley Country Club in Arkansas.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 7. (NR) Hardscrabble Country Club in Arkansas.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 8. (NR) Pinnacle Country Club in Arkansas.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 9. (NR) Chenal Country Club: Founders in Arkansas.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 10. (NR) Chenal Country Club: Bear Den in Arkansas.
# 'NoneType' object has no attribute 'group'
#
#
# Issue finding ranking data for 1. (1) The Estancia Club in Arizona.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 2. (2) Forest Highlands Golf Club: Canyon in Arizona.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 3. (3) Whisper Rock Golf Club: Upper Course in Arizona.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 4. (5) Whisper Rock Golf Club: Lower Course in Arizona.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 5. (NR) Scottsdale National Golf Club: The Other Course in Arizona.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 6. (4) Stone Canyon in Arizona.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 7. (6) Pine Canyon in Arizona.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 8. (7) Desert Forest Golf Club in Arizona.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 9. (10) Forest Highlands Golf Club: Meadow in Arizona.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 10. (8) Desert Highlands Golf Club in Arizona.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 11. (13) Silverleaf Club in Arizona.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 12. (11) Desert Mountain Club: Chiricahua Course in Arizona.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 13. (12) Desert Mountain Club: Geronimo Course in Arizona.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 14. (9) Desert Mountain Club: Renegade Course in Arizona.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 15. (19) Scottsdale National Golf Club: Mineshaft in Arizona.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for

# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 6. (5) Lexington Country Club in Kentucky.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 7. (7) Big Spring Country Club in Kentucky.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 8. (8) Traditions Golf Club in Kentucky.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 9. (6) University of Louisville Golf Club in Kentucky.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 10. (10) Persimmon Ridge Golf Club in Kentucky.
# 'NoneType' object has no attribute 'group'
#
#
# Issue finding ranking data for 1. (1) Squire Creek Country Club in Louisiana.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 2. (2) The Country Club of Louisiana in Louisiana.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 3. (NR) Metairie Country Club in Louisiana.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 4. (5) TPC Louisiana in Louisiana.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 5. (NR) The Country Club At Golden Nugget: Golden Nugget in Louisiana.
# 'NoneType' object has no attribute 'group'
#
#
# Issue finding ranking data for 1. (1) The Country Club: The Main Course in Massachusetts.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 2. (3) Myopia Hunt Club in Massachusetts.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 3. (2) Old Sandwich Golf Club in Massachusetts.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 4. (5) Essex County Club in Massachusetts.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 5. (4) The Kittansett Club in Massachusetts.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 6. (6) Boston Golf Club in Massachusetts.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 7. (7) Eastward Ho! in Massachusetts.
# 'NoneType' object has no attribute 'group'
#
# Issue finding ranking data for 8. (8) Sankaty Head Golf Club in Massachusetts.
# 'NoneType' object has no attribute 'group'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[62], line 41
#      38     print(f"Issue finding ranking data for {course} in {state}.\n{e}\n")
#      40 try:
# ---> 41     location = geocoder.bing(f"{course_name} {city}, {state_acryn}", key=bing_api_key).json
#      42     latitude = location['lat']
#      43     longtitude = location['lng']
#
# File c:\Users\andys\.conda\envs\smallprojectsenv\lib\site-packages\geocoder\api.py:365, in bing(location, **kwargs)
#     355 def bing(location, **kwargs):
#     356     """Bing Provider
#     357
#     358     :param ``location``: Your search location you want geocoded.
#    (...)
#     363         > reverse
#     364     """
# --> 365     return get(location, provider='bing', **kwargs)
#
# File c:\Users\andys\.conda\envs\smallprojectsenv\lib\site-packages\geocoder\api.py:198, in get(location, **kwargs)
#     196     if method not in options[provider]:
#     197         raise ValueError("Invalid method")
# --> 198 return options[provider][method](location, **kwargs)
#
# File c:\Users\andys\.conda\envs\smallprojectsenv\lib\site-packages\geocoder\base.py:410, in MultipleResultsQuery.__init__(self, location, **kwargs)
#     407 self._before_initialize(location, **kwargs)
#     409 # query and parse results
# --> 410 self._initialize()
#
# File c:\Users\andys\.conda\envs\smallprojectsenv\lib\site-packages\geocoder\base.py:457, in MultipleResultsQuery._initialize(self)
#     455 def _initialize(self):
#     456     # query URL and get valid JSON (also stored in self.json)
# --> 457     json_response = self._connect()
#     459     # catch errors
#     460     has_error = self._catch_errors(
#     461         json_response) if json_response else True
#
# File c:\Users\andys\.conda\envs\smallprojectsenv\lib\site-packages\geocoder\base.py:479, in MultipleResultsQuery._connect(self)
#     475 self.status_code = 'Unknown'
#     477 try:
#     478     # make request and get response
# --> 479     self.response = response = self.rate_limited_get(
#     480         self.url,
#     481         params=self.params,
#     482         headers=self.headers,
#     483         timeout=self.timeout,
#     484         proxies=self.proxies
#     485     )
#     487     # check that response is ok
#     488     self.status_code = response.status_code
#
# File c:\Users\andys\.conda\envs\smallprojectsenv\lib\site-packages\geocoder\base.py:510, in MultipleResultsQuery.rate_limited_get(self, url, **kwargs)
#     508 def rate_limited_get(self, url, **kwargs):
#     509     """ By default, simply wraps a session.get request"""
# --> 510     return self.session.get(url, **kwargs)
#
# File c:\Users\andys\.conda\envs\smallprojectsenv\lib\site-packages\requests\sessions.py:600, in Session.get(self, url, **kwargs)
#     592 r"""Sends a GET request. Returns :class:`Response` object.
#     593
#     594 :param url: URL for the new :class:`Request` object.
#     595 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     596 :rtype: requests.Response
#     597 """
#     599 kwargs.setdefault("allow_redirects", True)
# --> 600 return self.request("GET", url, **kwargs)
#
# File c:\Users\andys\.conda\envs\smallprojectsenv\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File c:\Users\andys\.conda\envs\smallprojectsenv\lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File c:\Users\andys\.conda\envs\smallprojectsenv\lib\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File c:\Users\andys\.conda\envs\smallprojectsenv\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File c:\Users\andys\.conda\envs\smallprojectsenv\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File c:\Users\andys\.conda\envs\smallprojectsenv\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File c:\Users\andys\.conda\envs\smallprojectsenv\lib\http\client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File c:\Users\andys\.conda\envs\smallprojectsenv\lib\http\client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File c:\Users\andys\.conda\envs\smallprojectsenv\lib\http\client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File c:\Users\andys\.conda\envs\smallprojectsenv\lib\socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
ts = "1. (1) Moose Run Golf Course: Creek"


match = re.search(r'^(\d+)', ts)
if match:
    print(f"Current Ranking: {match.group(1)}")

match = re.search(r'(\d+)\s*\((NR|NEW|\d+)\)', ts)
if match:
    print(f"Past ranking: {match.group(1)}")
# Out:
# Current Ranking: 1

# %% [markdown]
# # Golfweek

# %%
golfweek_public_courses_url = "https://golfweek.usatoday.com/lists/golfweeks-best-2023-courses-you-can-play-top-100-u-s-public-access-golf-ranking/"
response = requests.get(golfweek_public_courses_url)
html_content = response.text
soup = BeautifulSoup(html_content, "html.parser")
courses = [c.get_text() for c in soup.find_all('p') if (c.get_text()[0].isdigit() or c.get_text()[1].isdigit())]
courses = [c if c[0].isdigit() else c[1:] for c in courses]

# %%
golfweek_public = pd.DataFrame(columns=["CourseName","Played", "Date", "Notes", "CurrentRanking", "PastRanking","PanelistRating", "City", "State", "Country", "Architect", "Latitude", "Longitude"])

for count, course in enumerate(courses):

    current_ranking = course.split(".")[0]
    
    if "*" in course:
        last_ranking = "NEW"
    else:
        last_ranking = next((x for x in re.findall(r'(?:\((\d+)\)|T(\d+))', course.split("\n")[0])[0] if x), None)

    panelist_rating = float(re.search(r'\b\d+\.\d{2}\b', course).group())
    
    course_name_regex = re.search(r'\. (.+?)(?: \((?:T\d+|\*|\d+)\)|\*\s)', course)
    if course_name_regex:
        course_name = course_name_regex.group(1)


    location_regex = re.search(r'(?<=\n)(.+?)(?=\;)', course)
    if location_regex:
        city_and_state = location_regex.group(0).split(", ")

        city = city_and_state[0]
        state = state_mapping.get(city_and_state[1])

    location = geocoder.bing(f"{course_name} {city}, {state}", key=bing_api_key).json    
    latitude = location['lat']
    longtitude = location['lng']
    country = location['country']

    architect = re.findall(r'(?<=;\s)([^()]+)(?=\s\()', course)[0]

    golfweek_public.loc[len(golfweek_public)] = [course_name, "", "", "", current_ranking, last_ranking, panelist_rating, city, state, country, "-", latitude, longtitude]

# %% [markdown]
# # Create Excel Document

# %%
with pd.ExcelWriter('all_course_ratings.xlsx', engine='xlsxwriter') as excel_writer:
    golf_digest_public.to_excel(excel_writer, sheet_name="GD - Best USA Public 23-24", index=False)
    golfweek_public.to_excel(excel_writer, sheet_name="GW - Best USA Public 23-24", index=False)

    for state in states_data:
        states_data[state].to_excel(excel_writer, sheet_name = f"{state} - GD", index=False)
